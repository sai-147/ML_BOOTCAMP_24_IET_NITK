# %% [markdown]
# # 🧑‍🏫 Task 1 Part 1: Building a Spam Classifier with Naive Bayes
# In this exercise, you'll implement a spam classifier using the **Naive Bayes algorithm** . You'll work with email data to classify messages as spam or non-spam (ham). Follow the steps below and fill in the code where indicated.
#
# **Objective:** Implement all key components of an ML pipeline (except for data handling).
#
# **Allowed Libraries:** `pandas`, `numpy`
#
# **Not Allowed:** Any pre-built ML algorithms or functions like those from `sklearn`.
#
# Follow the instructions step-by-step and answer the questions!

# %% [markdown]
# ## Step 1: Data Loading and Preprocessing
# First, let's load and examine our data.

# %%
# Load the data
# TODO: Load the 'emails.csv' file into a DataFrame called 'emails'
import pandas as pd
emails = pd.read_csv('emails.csv')# Your code here

# %%
# Display the first few rows
print(emails.head())

# HINT: Use pd.read_csv() to load the data
# HINT: The DataFrame should have 'text' and 'spam' columns
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
print(emails.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5728 entries, 0 to 5727
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5728 non-null   object
#  1   spam    5728 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 89.6+ KB
# None

# %%
emails.isnull().sum().sum()
# Out:
# 0

# %%
#Analyse the data and remove or modify rows with missing or invalid values

# %% [markdown]
# ## Step 2: Text Preprocessing
# We need to process each email to extract unique words.

# %%
def process_email(text):
    """
    Convert email text to a list of unique, lowercase words
    
    Parameters:
        text (str): The email text
    
    Returns:
        list: List of unique words in the email
    """
    # TODO: Implement the preprocessing function
    # 1. Convert text to lowercase
    # 2. Split into words
    # 3. Remove duplicates
    text=text.lower()
    text=text.split()
    text=list(set(text))
    return text
    # Your code here

    # HINT: Use text.lower() for lowercase conversion
    # HINT: Use split() to convert text to words
    # HINT: Use set() to remove duplicates
    pass

# %%
# Apply preprocessing to all emails
for text in emails["text"]:
    text=process_email(text)
    print(text)
    emails
# Out:
# ['full', 'will', 'organization', 'clear', 'provided', 'three', 'use', 'drafts', 'changes', 'surethat', 'irresistible', 'look', 'suqgestions', 'world', 'market', 'made', 'do', 'nowadays', 'our', 'and', 'portfolio', 'its', 'for', 'aim', 'all', 'formats', 'catchy', 'logo', 'hotat', 'distinctive', 'automaticaily', 'identity', 'extra', 'system', 'content', 'naturally', 'logos', 'of', 'you', 'specially', 'this', 'good', 'done', 'amount', 'corporate', 'really', 'statlonery', 'be', '_', 'no', 'company', 'your', 'become', 'letsyou', 'not', 'website', 'within', 'unlimited', 'much', 'outstanding', 'change', 'result', 'convenience', 'promptness', 'days', 'effective', 'benefits', 'creativeness', 'subject:', 'ordered', 'provide', 'here', 'gaps', 'recollect', 'affordability', 'with', 'ieader', 'love', 'are', 'list', 'marketing', "'", 'structure', 'products', 'hand', 'image', 'that', 'see', '%', '-', 'promise', 'through', 'is', ',', 'make', 'iogo', 'stylish', 'fees', ';', 'shouldn', 'reflect', ':', 'budget', 'but', 'information', 'isguite', 'hard', 'stationery', 'easier', 'interested', 'a', 'havinq', 'at', '100', 'original', '.', 'business', 'break', 'the', 'ciear', 'isoverwhelminq', 'efforts', 'we', 'it', 'collaboration', 'easy', 'task', 'lt', 't', 'more', 'guaranteed', 'satisfaction', 'in', 'even', 'have', 'to', 'without', 'practicable', 'management']
# ['waterway', 'plain', 'diffusion', 'edt', 'nameable', 'slung', 'stock', 'the', 'no', 'pepperoni', 'deoxyribonucleic', 'chesapeake', 'merrill', 'muzo', 'not', 'herald', 'is', 'yes', 'continuant', 'attire', 'pirogue', 'earmark', 'perspicuous', 'kansas', 'libretto', 'incredible', 'duane', 'albeit', 'clockwork', 'chisel', 'bedtime', 'segovia', 'inflexible', 'huzzah', 'hall', 'boar', 'optima', 'esmark', 'try', 'and', 'morristown', 'superior', 'fanny', 'gunslinger', 'but', 'hawthorn', 'clothesman', 'like', 'chronography', 'subject:', 'chameleon', 'sapling', 'palfrey', 'tight', 'group', 'trading', 'colza', 'einsteinian', 'tanzania', 'attainder', 'or', 'penultimate', 'hepburn', 'ramble', 'mcdougall']
# ['approved', 'this', 'extended', '1', 'im', '.', 'advantage', '3', 'rate', 'that', 'no', 'the', 'fixed', '72', 'your', '169', '-', 'post', 'home', 'being', 'visit', 'homes', 'look', 'website', ',', 'is', 'take', 'been', 'ask', 'pre', 'form', 'we', 'easy', 'show', 'made', 'our', 'complete', 'foward', 'credit', 'minute', 'offer', 'loan', 'and', 'time', 'opportunity', 'for', '454', 'all', 'hearing', 'subject:', 'homeowner', 'unbelievable', '$', 'pittman', 'wanting', 'have', 'in', 'way', 'new', 'to', 'unconditionally', 'factor', 'from', 'a', 'at', 'limited', 'approval', 'of', 'you', 'dorcas']
# ['this', '338', 'goldengraphix', 'special', '8102', '.', '5110', 'click', '@', 'version', 'rd', 'phone', 'com', '&', 'printable', '-', 'order', 'fax', ',', 'is', 'color', 'mail', 'solicitation', 'canyon', 'form', 'azusa', '(', 'our', '91706', 'golden', '!', 'printing', 'graphix', 'and', '4', ':', 'for', '626', 'ca', 'information', 'an', 'subject:', 'additional', 'e', 'advertisement', 'message', '/', 'here', 'pdf', 'irwindale', 'now', '8090', 'ramsey', 'format', 'or', 'request', 'a', ')', 'of']
# ['?', "'", '.', 'marriage', 'along', 'finish', 'be', 'great', 'the', 'by', 'not', 'yet', ',', 'is', 'ended', 'me', 'it', 'best', 'ain', 'do', '!', 'd', 'compatibility', 'cds', 't', 'all', 'software', 'comedies', 'subject:', 'old', 'tradgedies', 'death', 'get', 'here', 'have', 'with', 'to', 'from', 'money', 'grow', 'are']
# ['phar', 'introduce', '5', 'nice', '.', 'welcome', 'hello', 'worldwide', 'great', 'countries', 'the', 'um', 'allusion', '%', '-', 'ieading', 'ov', '150', 'shakedown', 'andmanyother', ',', 'ac', 'l', 'is', 'ntiaiity', 'hlpplng', 'sav', 'groundsel', 'we', 'over', 'as', 'v', 'nnews', 'total', 'er', 'day', 'maceuticai', 'online', '75', '!', 'confide', 'op', 'pleased', 'medzonline', 'leisure', 'subject:', 'e', 'r', 'helter', 'bestow', 'va', 'miilion', 'devitalize', 'shops', 'polite', 'sh', 'cosmopolitan', 'tosher', 'ourselves', 'inexpiable', 'in', 'have', 'to', 'coadjutor', 'blister', 'a', 's', 'ag', 'confidant', 'one', 'felicitation', 'customers', 'of', 'are']
# ['email', '35', 'allows', 'smail', 'rock', '1934', 'never', 'seven', 'kind', 'measure', 'contained', 'than', 'previousiy', 'preservation', 'lightning', 'can', 'party', 'remember', 'read', 'for', 'services', 'newsietter', 'chemica', 'action', 'accounting', ')', 'especia', 'lucrative', 'fueis', '20', 'limited', 'history', 'unsecured', 'september', 'differ', 'no', 'omit', 'out', 'by', 'sector', '2', 'speciaily', 'none', 'including', 'constant', '(', 'outstanding', 'invoive', 'service', 'time', 'create', 'b', 'necessary', 'provide', 'here', 'maybe', 'verge', 'wi', 'from', 'safe', 'confiict', 'must', 'enabie', 'others', 'application', 'thorough', 'advantage', 'features', 'requires', 'forrester', 'pioneer', 'space', 'guarantee', 'investors', 'moment', 'projects', 'through', 'is', 'ega', 'compensation', '11', 'operating', 'notice', 'developing', 'compieteness', 'emergency', 'gives', 'noting', 'transmit', 'play', 'beiieves', 'material', 'construed', 'valuable', 'need', 'represent', 'inc', 'ocaies', 'a', 'customers', 'at', 'automation', 'personnel', '.', 'aiso', 'exampies', 'integration', 'terms', 'micro', 'tags', 'officer', 'works', '|', '21', 'nuciear', 'websites', 'economy', 'companies', 'entry', 'limit', 'tracking', 'excitement', 'majority', 'near', 'aiong', 'occur', '/', 'lose', 'investment', 'in', 'even', 'timing', 'motion', 'understands', 'physical', 'favorabie', 'price', 'june', 'aware', 'foresee', 'advises', 'trapped', 'provided', 'government', 'huge', 'historica', 'releases', 'supply', 'completed', 'related', 'ports', 'high', 'certain', 'only', 'wirelessly', 'do', 'parties', 'fiiings', 'inciuding', 'report', 'stockhoider', 'happening', 'does', 'sma', 'misleading', 'expects', 'focus', 'therein', 'big', 'innovative', 'advisor', 'personal', 'rfid', 'reiiance', 'position', 'advancing', 'statements', 'conditions', 'returns', 'of', 'seiected', 'industry', 'present', 'filiing', 'materiais', 'mining', 'emai', 'segments', 'wil', 'risks', 'evaiuate', 'become', 'anticipates', 'spending', 'ocations', 'within', 'based', 'many', 'state', 'truiy', 'readers', 'danger', 'such', 'believes', 'before', 'mines', 'appiication', 'pertaining', 'short', 'refining', 'contains', 'reliabie', "'", 'frequency', 'further', 'referenced', 'investments', 'products', 'great', 'results', 'percent', 'chain', 'see', 'oi', 'rf', '&', 'discioses', 'where', 'u', 'yet', 'couid', 'was', 'tweive', 'securities', 'over', 'states', 'assist', 'wouid', 'deemed', 'research', 'achieve', 'machines', 'y', 'identify', 'two', 'calif', 'view', 'sources', 'ob', 'these', 'registered', 'safety', 'paid', 'basis', 'given', 'money', 'ensuring', 'into', 'review', 'business', 'require', 'hands', 'reiated', 'facts', 'detection', 'vinoble', 'resuits', 'events', 'solicitation', 'protective', 'we', 'it', 'compiiance', 'increasing', 'beliefs', 'wire', 'transportation', 'may', 'expanding', 'security', 'changed', 'locations', 'seek', 'have', 'forward', 'cause', 'water', 'sec', 'although', 'too', 'conflicted', 'other', 'resource', 'tax', '5', 'wireiessly', 'believe', 'due', 'use', 'homeland', 'afford', 'se', 'resuiting', 'rocket', 'as', '12', 'needed', 'hot', 'our', 'sensors', 'transit', 'opportune', 'potential', 'foreseeable', 'natura', 'and', 'discussions', '27', 'actua', 'all', 'there', 'speed', 'goals', 'radio', 'expected', 'advertisement', '$', 'any', 'predictions', 'toois', 'acceptance', 'ourselves', 'personne', 'nationa', 'extraction', 'aiways', 'capitalize', 'estimates', 'risk', 'you', 'welis', 'director', 'fa', 'news', 'what', 'commodities', 'numerous', 'be', 'projections', 'might', 'capital', 'featured', 'already', 'airports', 'sectors', 'landscape', 'who', 'factors', 'effort', 'giga', 'possible', 'providing', 'set', 'eclipse', 'whiie', 'shareholder', 'wrong', 'filings', 'why', 'investing', 'faciiities', 'factua', 'otcbb', 'pubiic', 'which', 'subject:', 'diiigence', 'interest', 'threat', 'united', 'retai', 'with', '17', '2005', 'actions', 'ail', 'today', 'woridwide', 'rapidly', 'saie',  ...
# ['buy', 'this', 'exactiy', '?', 'viagra', '.', 'what', 'be', 'great', 'provided', 'that', 'the', 'lot', 'your', 'now', '-', 'than', 'not', 'yet', 'imagine', 'minutes', 'cannot', 'is', 'are', 'mix', 'over', 'we', 'within', 'it', 'country', 'can', '!', 'advantages', 'hours', 'getting', 'cialis', '10', 'for', 'save', 'want', 'ready', 'start', 'like', 'man', 'real', 'subject:', 'right', 'when', 'cialls', 'has', 'any', 'just', 'get', 'here', 'have', 'even', 'in', 'thing', 'with', 'bed', 'to', 'tried', 'errrectlon', 'iasts', 'money', '36', 'a', 'ship', 'of', 'you', 'effect', 'aicohol']
# ['09', '5', 'com', 'fjt', 'home', '23', 'jan', '2002', '8', 'mtpi', 'following', '27', 'for', 'reach', 'on', 'did', '+', '25', ')', 'of', 'mts', '6', '0100', '7059', 'msexch', 'co', 'your', 'not', 'sun', 'based', '(', '75', 'recognized', '2001', 'subject:', 'id', 'i', '000', 'telecom', 'q', 'unknown', '24', '-', ',', 'is', 'l', 'subject', ';', 'c', '32', ':', 'mon', '=', 'ims', 'name', 'a', 'ptt', 'original', 'sent', '.', 'business', '@', 'recipient', 'the', '21', 'undeliverable', 'kpn', '0', 'grownups', 'feb', '13', 'd', '4', 'p', '70590202251232', 'message', 's', 'us', 'tfi']
# ['buy', 'this', 'exactiy', '?', 'viagra', '.', 'what', 'aicohoi', 'be', 'great', 'provided', 'that', 'the', 'lot', 'your', '-', 'than', 'not', 'yet', 'imagine', 'minutes', 'cannot', 'is', 'are', 'mix', 'over', 'we', 'within', 'it', 'country', 'can', '!', 'advantages', 'hours', 'getting', 'cialis', '10', 'for', 'save', 'want', 'ready', 'start', 'like', 'man', 'real', 'subject:', 'right', 'when', 'cialls', 'has', 'any', 'just', 'get', 'here', 'have', 'even', 'in', 'thing', 'with', 'bed', 'to', 'tried', 'errrectlon', '36', 'money', 'ship', 'a', 'now', 'lasts', 'of', 'you', 'effect']
# ['built', 'com', 'future', 'strip', 'major', 'high', 'towers', 'and', 'expected', 'on', 'just', '+', 'highrise', 'you', 'buy', 'this', 'please', 'learn', '3', 'be', 'by', 'years', 'been', 'pre', 'including', 'within', 'excluded', 'wish', 'phase', '60', 'word', 'icon', 'subject:', 'next', 'boom', 'rises', 'interest', 'available', 'fast', '000', 'pricing', 'with', 'mailings', 'from', 'rise', 'sky', 'are', 'others', 'list', "'", 'becoming', 'vegas', 'that', '-', 'las', 'is', ',', 'among', 'subject', ':', 'join', 'early', 'cosmopolitan', 'now', 'a', 'at', 'sent', '.', 'trump', 'city', 'the', 'remove', 'around', 'http', '!', 'line', 'begun', '4', 'construction', 'reply', 'metropolitan', 'condominiums', 'has', 'more', 'message', 'turnberry', '/', 'comif', '30', 'in', 'new', 'first', 'to', 'www', 's', 'one', 'mgm', 'realty', 'verticallv']
# ['buy', 'this', '?', 'viagra', '.', 'what', 'ship', 'be', 'great', 'provided', 'that', 'the', 'your', 'now', '-', 'than', 'not', 'yet', 'imagine', 'minutes', 'cannot', 'is', 'iot', 'are', 'mix', 'over', 'we', 'within', 'it', 'country', 'can', '!', 'hours', 'getting', 'with', '10', 'for', 'save', 'want', 'ready', 'start', 'like', 'man', 'real', 'subject:', 'when', 'cialls', 'has', 'any', 'just', 'get', 'here', 'riqht', 'have', 'even', 'in', 'thing', 'exactly', 'bed', 'to', 'tried', 'errrectlon', 'advantaqes', 'money', 'ciaiis', 'a', 'iasts', '36', 'of', 'you', 'effect', 'aicohol']
# ['email', 'will', 'brighten', 'those', 'site', 'local', 'look', 'exact', 'market', 'as', 'whiten', 'product', 'best', 'our', 'if', 'considered', 'fraction', 'and', 'for', 'all', 'like', '$', 'on', 'longer', '300', 'system', 'of', 'you', 'their', 'this', 'learn', 'special', 'what', 'click', 'no', 'how', 'your', 'visit', 'member', 'network', 'including', 'usually', 'day', 'affiliate', 'an', 'subject:', 'available', 'here', 'with', 'back', 'from', 'are', 'today', "'", 'products', 'bright', 'internet', 'guarantee', ',', 'is', 'white', 'same', 'show', 'so', 'between', ':', 'using', 'professionally', 'get', 'now', 'money', 'a', 'at', 'receiving', '?', '.', 'costs', 'via', 'dentist', 'the', 'uses', 'professional', 'receive', 'unsubscribe', '500', 'cost', 'teeth', 'whitening', 'we', 'it', 'promotions', '!', 'comparison', 'would', 'more', '30', 'have', 'in', 'know', 'to', 's', 'then']
# ['email', 'dow', 'response', '1934', 'never', 'seven', 'kind', 'pink', 'contained', 'equity', 'previousiy', 'find', 'can', 'party', 'remember', 'read', 'associate', 'for', 'reason', 'action', 'accounting', ')', '20', 'history', '70', 'unsecured', 'good', 'week', 'year', 'spiit', 'earnings', 'differ', 'no', 'omit', 'out', 'by', 'tockhoider', 'years', '2', 'significance', 'none', 'including', '(', 'outstanding', 'materialiy', 'sti', 'time', 'b', 'necessary', 'mone', 'here', 'verge', 'wi', 'from', 'confiict', 'must', 'others', 'thorough', 'nearly', '15', 'rich', 'fold', 'pioneer', 'guarantee', 'investors', 'asdi', 'projects', 'obviousiy', 'through', 'is', 'cannot', 'compensation', 'wall', 'stoc', 'silver', 'operating', 'notice', 'signed', 'developing', 'compieteness', 'so', 'noting', 'right', 'material', 'construed', 'need', 'thing', 'represent', 'inc', 'foreseeabie', 'a', 'doubled', 'customers', 'at', 'president', 'ow', 'expiored', '.', 'exampies', 'terms', 'micro', 'michael', 'recommendation', 'officer', '21', '|', '500', 'websites', '0', 'avoid', 'produce', 'dragon', 'companies', 'add', 'enter', 'majority', '26', 'near', 'occur', 'investment', 'in', 'timing', 'sto', 'nothing', 'activities', 'understands', 'june', 'price', 'aware', 'foresee', 'advises', 'discloses', 'upturn', 'provided', 'com', 'small', 'completed', 'related', 'certain', 'coiorado', 'parties', 'fiiings', 'inciuding', 'report', 'happening', 'does', 'sma', 'expects', 'focus', 'therein', 'big', 'advisor', 'reiiance', 'advancing', 'position', 'statements', 'of', 'industry', 'maximum', 'mining', 'emai', 'wil', 'very', 'risks', 'anticipates', 'extraordinary', 'proposed', 'within', 'based', 'selected', 'many', 'bumper', 'enough', 'go', 'readers', 'suppiy', 'such', 'believes', 'before', 'prices', 'mines', 'increased', 'pick', 'pertaining', 'short', 'pittsburg', 'average', 'mountain', 'contains', 'said', "'", 'referenced', 'street', 'lead', 'percent', 'results', '&', 'developments', 'commenting', 'u', 'yet', 'was', 'couid', 'expect', 'over', 'securities', 'states', 'wouid', 'achieve', 'phenomenon', 'y', 'repsect', 'phoenix', 'vailey', 'two', 'sources', 'view', 'these', 'pwcglobal', 'wester', 'registered', 'transaction', 'paid', 'basis', 'given', 'rewards', 'split', 'into', 'review', 'business', 'plume', 'egal', 'reiated', 'facts', 'professional', 'resuits', 'events', 'solicitation', 'spelled', 'we', 'it', 'argest', 'intent', 'compiiance', 'ocated', 'another', 'beliefs', 'directors', 'wire', 'may', '4', 'expanding', 'seek', 'date', 'rights', 'boards', 'started', 'move', 'commodity', 'have', 'forward', 'cause', 'sec', 'too', 'conflicted', 'other', 'tax', 'diligence', '5', 'ook', 'due', 'essentially', 'three', 'use', 'resuiting', 'rocket', 'tocks', 'sustained', 'as', 'oretech', '12', '8', 'return', 'our', 'discussions', 'and', 'global', 'stress', '10', '27', 'all', 'jones', 'there', 'goals', 'westernsierramining', 'expected', 'advertisement', '$', 'any', 'predictions', 'acceptance', 'letter', 'twelve', 'extraction', 'aiways', 'estimates', 'risk', 'you', 'director', 'news', 'each', '3', '6', 'sharehoiders', 'dash', 'be', 'buoyant', 'projections', 'numerous', 'might', 'capital', 'featured', 'effort', 'factors', 'providing', 'set', 'shareholder', 'filings', 'why', 'investing', 'mean', 'factua', 'afoot', 'pubiic', 'industrial', 'which', 'trying', 'subject:', 'boom', 'affiiiate', 'interest', 'with', 'tock', 'sierra', '17', '2005', 'coopers', 'actions', 'ail', 'subscribers', 'today', 'suppiies', 'issued', 'thousand', 'that', 'announced', 'exploration', 'operates', 'shail', 'act', 'constitutes', '-', 'ooking', 'identified', 'second', ';', 'anticipated', 'representative', 'trade', ':', 'materials', 'respective', 'but', 'nev', 'waterhouse', 'wsrm', 'term', 'impact', 'information', 'specialiy', 'looking', 'additional', 'third', 'pians', 'reiiable', 'al', 'get', 'aiignment', '"', 'long', 'fifty', 'sites', 'approved', 'profits', 'actual', 'disclaimer', 'indicative', 'stock', 'earned', ...
# ['please', 'this', 'instructions', 'protect', '.', 'misrepresentation', 'click', 'be', 'maintain', 'that', 'conclusion', 'the', 'because', 'your', 'bellow', '-', 'member', 'effort', 'order', 'patience', ',', 'cannot', 'been', 'safeharbor', 'section', 'suspension', 'we', 'suspended', 'departmentebay', 'it', 'until', 'notice', 'can', 'our', 'led', 'regards', 'procedures', 'button', 'may', 'getting', 'and', 'time', ':', 'for', 'user', 'thank', 'taken', 'an', 'security', 'fpa', 'such', 'took', 'subject:', 'reinstated', 'on', 'restored', 'compromised', 'dear', 'in', 'have', 'know', 'safely', 'identity', 'action', 'to', 'although', 'account', 'disclose', '9', 'ebay', 'investigative', 'safety', 'inc', 'of', 'you', 'cooperation']
# ['email', '1', 'will', 'never', 'provided', 'com', 'being', 'major', 'promoting', 'pe', 'find', 'only', 'our', 'if', 'per', 'sincerely', 'following', 'and', 'top', 'removed', 'any', 'fee', 'alta', 'etc', ')', 'position', 'pay', 'specialists', 'of', 'you', 'please', 'this', 'address', '6', 'click', 'type', 'be', 'company', 'very', 'permanently', 'your', 'out', 'not', 'website', 'immediately', 'unlimited', 'wish', '(', 'word', 'subject:', 'engine', 'engines', 'searchl', 'usa', 'url', 'with', 'from', 'promotional', 'last', 'are', 'list', "'", 'qualify', 'speedy', 'yahoo', ',', 'is', 'subject', 'net', 'place', ':', 'vista', 'msn', 'examples', 'valid', 'interested', 'now', '"', 'a', 'long', 'includes', 'at', 'going', '.', 'business', '@', 'via', 'search', 'the', 'respond', 'remove', 'canada', 'ex', 'placement', 'it', '!', 'line', 'contact', 'important', 'move', 'telefonica', 'traffic', 'guaranteed', 'qualified', 'in', 'first', 'to', 'promotion', 'include', 'promptly', 's', 'us', 'listing']
# ['100', 'hustles', 'legal', 'waits', '.', 'be', 'cowards', 'everything', 'courage', 'brand', '%', 'low', '-', 'him', 'who', 'is', ',', 'while', 'they', 'had', 'many', 'only', 'our', 'if', 'enough', 'software', 'would', 'subject:', 'prices', 'comes', 'guaranteed', 'name', 'to', 'he', 'at']
# ['119', '5', 'cd', 'immediate', 'reqards', 'site', '39', 'homesite', '59', '12', 'browse', 'find', 'french', 'best', 'our', 'and', 'for', 'all', 'like', '$', 'any', 'just', 'sp', ')', 'few', 'you', 'hello', 'week', 'qerman', 'iisted', '3', 'no', 'your', 'deiivery', '2', 'including', '(', 'many', 'availabie', 'software', 'subject:', 'available', 'with', '2005', 'pro', 'windows', 'others', 'versions', 'graphics', 'ianguaqe', 'version', 'download', '-', ',', 'is', 'wait', 'languages', 'xp', 'localized', 'offer', 'uk', ':', '2004', 'need', 'suite', 'lnternet', 'studio', 'corei', 'draw', '29', 'mx', '.', 'fuil', '95', 'exampies', 'professional', '49', 'we', 'norton', 'native', '!', 'lauraiee', 'security', 'would', 'dreamweaver', 'macromedia', 'in', 'to', 'spanish']
# ['union', 'alert', 'credit', 'national', 'confirm', '>', 'information', 'security', 'subject:', 'your', '-']
# ['analysis', 'lotus', 'project', 'corporations', 'full', 'will', '1000', 'successfully', 'com', 'site', 'call', 'cutting', 'small', 'challenges', 'leading', 'solutions', 'send', 'porting', 'systems', '#', 'section', 'cryptography', 'can', 'our', 'only', 'best', 'glad', 'if', 'fraction', 'fortune', 'and', 'for', 'services', 'all', 'happy', 'bring', 'coding', 'equivalent', 'on', 'standards', 'mistake', 'ibm', 'databases', 'foxpro', 'letter', 'or', 'specialists', ')', 'of', 'you', 'please', 'testing', 'develop', 'this', 'what', '3', 'click', 'ms', 'be', 'extranet', 'experienced', 'jrgbm', 'websphere', 'no', '1618', 'solution', 'your', 'by', 'development', 'not', 'employ', 'quality', 'century', '2', 'some', 'unix', 'based', '(', 'desktop', 'developers', 'teams', 'word', 'superior', 'consider', 'domino', 'tens', 'exclusive', 'weblogic', 'effective', 'fair', 'software', 'erp', 'scope', 'subject:', 'e', 'jdbc', 'b', 'provide', 'bill', 'completing', 'here', 'db', 'offshore', 'staffed', 'with', 'sending', 'from', 'windows', 'warehouses', 'design', 'list', 'uce', 'application', 'senate', "'", 'sql', 'oracle', 'working', 'that', 'consulting', 'internet', 'phone', 'activex', 'asp', 'established', '-', 'u', 'number', 'partnerships', 'projects', ',', 'is', 'integrate', 'subject', 'technologies', 'ee', 'over', 'wireless', 'operating', 'variables', 'mobile', 'problem', 'human', 'c', 'net', 'crm', 'offered', 'so', 'quotes', ':', 'budget', 'but', 'pleased', 'java', '301', 'ref', 'dear', 'need', 'st', 'informix', 'represent', 'edge', 'suite', 'title', 'info', 'a', 'at', 'includes', 'professionals', 'providers', 'resources', '100', 'developed', 'bea', '?', 'stopped', 'platforms', '.', 'deliver', 'sure', 'business', 'midsize', 'domestic', 'recipient', 'the', 'technology', 'rates', 'sybase', 'wml', 'intranet', 'remove', 'received', '21', 'well', 'unsubscribe', 'cost', 'hundreds', 'coldfusion', 'we', 'it', 'corba', 'companies', '!', 'line', 'applications', 'transmissions', 'web', 'details', 'most', 'data', 'odbc', 'reply', 'security', 'would', 'scale', 'wap', 'record', 'cycle', 'both', 'efficient', 'more', 'wide', '/', 'accordingly', 'qualified', 'have', 'in', 'know', 'quote', 'to', 'include', 'idea', 's', 'management', 'modern', 'free']
# ['buy', 'approved', 'shippinq', '?', "'", 'click', '@', 'be', 'unsatisfied', 'great', 'the', 'your', 'bs', 'by', 'pri', 'is', ',', 'girl', 'men', 'wait', 'variety', 'it', 'med', 'until', 'visa', 'another', 'best', 'es', '!', 'bbb', 'choose', 'and', 't', 'for', 'happy', 'verified', 'warehouse', 'subject:', '$', 'any', 'store', 'finds', 'here', 'fast', 'riqht', 'guaranteed', 'with', 'she', 'to', 'don', 'from', 'potency', 'a', 'love', 'llcensed', 'of', 'you', 'effect']
# ['creatorstoll', '658', 'control', 'com', 'site', '9978', 'best', 'and', 'panel', 'my', 'for', 'services', 'want', 'happy', 'recreate', 'copy', 'or', 'etc', 'you', '800', 'fi', 'part', 'wanted', 'be', 'your', 'website', 'setup', 'some', 'hi', 'brainstorm', 'mean', 'ability', 'clothingplus', 'create', 'subject:', 'prices', 'i', 'here', 'with', "'", 'initial', 'could', 'products', 'that', 'electronics', 'easily', '-', '206', 'is', ',', 'ext', 'after', 'offer', ':', 'when', 'store', 'jasononline', 'name', 'now', 'a', 'recently', 'visited', 'master', 'give', '.', 'business', 'pictures', 'the', 'remove', 'websites', 'we', 'add', 'regards', 'jason', 'http', '!', 'wearable', 'friendly', 'contact', 'user', 'help', 'would', 'text', '/', 'ideas', 'in', 'have', 're', 'to', 'www', 's', 'free']
# ['price', 'level', 'orders', 'three', 'changes', 'remembered', 'look', 'can', 'and', 'top', 'for', 'formats', 'logo', 'identity', 'or', 'fit', 'of', 'you', 'creative', 'done', 'lost', 'special', 'amount', 'corporate', 'be', 'company', 'your', 'sometimes', 'website', 'competitive', 'unlimited', 'ioqo', 'needs', 'days', 'about', 'subject:', 'provide', 'fast', 'life', 'design', 'fiexible', 'takes', 'image', 'quaranteed', 'see', '-', 'dynamic', 'is', 'among', ',', 'iogo', 'turnaround', ';', ':', 'rhythm', 'additional', 'right', 'get', 'stationery', 'now', 'discounts', 'a', 'at', '.', 'business', 'sure', 'things', 'bulk', 'lot', 'oniy', 'variants', 'we', 'it', 'meet', 'contemporary', 'several', '!', 'competitors', 'say', 'packages', 'improvement', 'riqht', 'satisfaction', 'in', 'have', 'to', 'seconds', 'severai', 'too', 'wiil']
# ['others', 'medication', 'prescription', 'sinners', 'write', 'source', '.', 'what', "'", '?', 'friends', 'urgent', 'rule', 'lead', 'the', 'no', 'doing', 'your', 'soul', 'is', ',', 'meds', 'trusted', ';', 'best', 'less', '4', ':', 'for', 'most', 'there', 'like', 'subject:', 'gold', 'foes', 'anger', 'life', 'question', 'generic', 's', 'other', 'one', 'of', 'you', 'are']
# ['prescription', 'source', '.', 'paints', 'ordering', 'overgrown', 'fairly', 'conclusion', 'the', 'your', 'poet', '-', 'where', 'home', 'thinking', 'hands', 'not', 'than', 'is', 'years', 'winning', 'health', 'brains', 'simply', 'online', 'child', 'place', 'and', 'for', 'tired', 'his', 'always', 'information', 'man', 'an', 'play', 'cards', 'subject:', 'thirty', 'old', 'when', 'has', 'more', 'on', 'got', 'rely', 'in', 'should', 'with', 'a', 'us', 'one', 'of', 'you']
# ['fertility', 'will', 'com', 'php', 'home', 'adam', 'only', 'our', 'rm', 'if', 'pretending', 'and', 'my', 'thanks', 'for', 'does', 'all', 'helping', 'karla', 'like', 'spice', 'motility', 'on', 'though', 'sperm', 'chorally', 'cum', 'of', 'speaks', 'this', 'missing', 'really', 'sex', 'be', 'lucky', 'frank', 'guzzle', 'morphology', 'not', 'improved', 'stars', 'quality', 'been', 'erotic', 'making', 'go', 'enjoying', 'up', 'subject:', 'i', 'ordered', 'point', 'here', 'jealous', 'ky', 'usa', 'life', 'from', 'porn', 'j', 'gigantic', 'them', 'veteran', 'that', 'see', 'blend', '-', 'romano', 'male', 'was', ',', 'is', 'make', 'worth', 'ever', 'own', 'shot', 'rocks', ':', 'two', 'get', 'need', 'thing', '"', 'now', 'money', 'a', 'customer', 'pregnant', '?', '.', 'spur', 'the', 'off', 'sheep', 'works', 'san', 'me', 'we', 'it', 'fountain', 'http', '!', 'improve', 'anthony', 'help', 'would', 'francisco', 'homemade', 'films', 'has', 'movies', '/', 'dollar', 'have', 'even', 'in', 'to', 'm', 'disturbed', 'us', 'one', 'end', 'girlfriend']
# ['itfound', '119', 'onthis', 'answer', 'full', 'will', 'site', 'use', 'than', 'major', 'found', 'link', 'world', 'find', 'can', 'only', 'our', 'best', 'and', 'for', 'losing', '$', 'any', 'on', 'discover', 'don', ')', 'of', 'you', 'click', 'how', 'your', 'website', 'seen', 'meta', 'submission', 'change', 'many', '(', 'effective', 'subject:', 'here', 'engines', 'rise', 'findyour', 'submit', '360', 'are', 'list', "'", 'youlosing', 'worlds', 'them', 'that', 'see', 'equation', 'cannot', 'over', 'simple', 'so', 'connecting', 'research', 'but', 'professionally', 'thepower', '=', 'get', 'enginelistings', 'wouldamaze', 'a', 'customers', 'keywords', '?', '.', 'business', 'search', 'the', 'notbeing', 'tags', 'amaze', 'shoppers', 'figure', 'they', 'around', 'we', '!', 'web', '97', 't', 'most', 'let', 'would', 'more', 'wide', 'lose', 'in', 'new', 'to', 'manage', 'us']
# ['70', 'successfull', 'warmish', '5', '.', 'nice', 'ers', 'o', 'worldwide', 'how', '%', 'oviform', 'your', 'perish', '-', 'u', 'iceblink', 'andmanyother', 'prl', 'l', 'ty', 'potted', 'over', 'hi', 'necrology', 'miliion', 'v', 'peeved', 'ces', 'excepting', 'our', 'coruscate', 'best', 'total', 'val', 'day', '!', 'lpplng', 'and', 'save', 'y', 'ra', 'ey', 'mon', 'cl', 'medlcatlons', 'shop', 'pothouse', 'subject:', 'slicker', 'lansquenet', 'countermine', 'nonary', 'i', 'laughter', 'n', 'rmzmail', 'cribriform', 'improper', 'sh', 'have', 'bacchic', 'to', 'placatory', 'confidentiaii', 'm', 'proven', 'a', 'g', 's', 'pha', '*', 'way', 'custom']
# ['70', 'poseur', 'ibidem', '.', '5', 'bionics', 'nice', 'trick', 'worldwide', 'banian', 'proposer', 'commissioned', '%', 'panoramic', 'your', '-', 'thhe', 'u', 'pharmz', 'andmanyother', 'is', 'ac', 'l', 'mail', 'confident', 'over', 'successfu', 'panjandrum', 'shlpplng', 'iaiity', 'incommodious', 'v', 'rlces', 'rousing', 'best', 'total', 'miliion', 'austerity', 've', 'val', 'day', 'televisional', '!', 'receivable', 'w', 'and', 'unbloody', 'save', 'y', 'forsaken', 'll', 'medlcatlons', 'shop', 'tangential', 'p', 'subject:', 'r', 'on', 'mone', 'did', 'ha', 'ho', 'inornate', '25', 'mg', 'to', 'm', 'proven', 'a', 'g', '*', 'customers', 'foreshown', 'pelagian', 'way']
# ['buy', 'this', 'exactiy', '?', 'viagra', '.', 'what', 'be', 'great', 'provided', 'that', 'the', 'lot', 'your', '-', 'than', 'not', 'yet', 'imagine', 'minutes', 'cannot', 'is', 'are', 'mix', 'over', 'we', 'within', 'it', 'country', 'can', '!', 'advantages', 'hours', 'getting', 'cialis', '10', 'for', 'save', 'want', 'ready', 'start', 'like', 'man', 'real', 'subject:', 'right', 'when', 'cialls', 'has', 'any', 'just', 'get', 'here', 'have', 'even', 'in', 'thing', 'with', 'bed', 'to', 'tried', 'errrectlon', '36', 'money', 'ship', 'a', 'now', 'lasts', 'of', 'you', 'effect', 'aicohol']
# ['cecks', '?', 'credit', 'cpproved', 'want', 'now', 'to', 'accept', 'aredit', 'no', '126432211', 'cards', 'subject:', 'it', 'do']
# ['bank', 'project', '5', 'supervision', 'response', 'will', 'shall', 'users', 'control', 'partner', 'arrive', 'disadvantages', 'use', 'continue', 'runs', 'government', 'future', 'doing', 'upon', 'look', 'also', 'faithfully', 'mail', 'un', 'self', 'foreign', 'law', 'as', 'contracts', 'eseimoku', 'can', 'our', 'do', 'party', 'accounts', 'matter', 'decide', 'disposition', 'york', 'and', 'managing', 'my', 'top', 'for', '10', 'all', '939134', 'there', 'mchineries', 'yourself', 'chase', 'reach', 'trust', 'anderson', '$', 'reason', 'any', 'put', 'acceptance', 'dollars', 'negotiate', 'ourselves', 'servants', 'or', ')', 'position', 'risk', 'of', 'you', 'operate', 'please', 'this', 'legal', 'address', 'present', 'acquire', 'committee', 'partnership', 'allowed', 'medium', 'be', 'finally', 'official', 'verification', 'no', 'apologise', 'democratic', 'company', 'soon', 'your', 'by', 'development', 'member', 'not', 'numbers', 'utmost', 'been', 'legitimate', 'transferring', 'however', 'within', 'including', 'forty', 'wish', 'mailman', '(', 'funds', 'days', 'about', 'delta', 'overseas', '400', 'discrete', 'which', 'an', 'linux', 'independent', 'subject:', 'charge', 'i', 'provide', 'am', 'treat', 'united', 'colleagues', 'secrecy', 'with', 'secondly', 'cbn', 'effected', 'account', 'j', 'nigeria', 'must', '14', 'sum', 'are', 'percentage', 'siphon', 'agreement', 'list', 'hence', "'", 'contract', 'working', 'that', 'perfect', 'delegated', 'founding', 'land', 'federal', 'transparency', 'sales', '-', 'monthly', 'fgn', 'number', 'virtue', 'through', 'fax', ',', 'power', 'is', 'cannot', 'subject', 'under', 'over', 'ensure', 'states', 'fees', 'named', 'nigerian', 'own', 'country', 'solicit', 'conviction', 'disbursement', 'supervising', 'place', ':', 'subscription', 'using', 'information', 'morgan', ']', 'hundred', 'looking', 'fund', 'presently', 'pdp', 'when', 'corporation', 'dear', 'transfer', 'executed', 'need', 'these', 'registered', 'name', 'seeking', 'now', 'paid', 'transaction', 'ie', 'nine', 'money', 'a', 'support', 'above', 'maintainer', 'ruling', 'listmaster', 'note', 'ilug', 'outside', 'into', 'furnish', 'confidentiality', '.', 'million', 'business', '@', 'thosand', 'the', 'terms', 'commission', 'because', 'communicate', 'millions', 'currently', 'highly', 'accrued', 'handled', 'suitable', 'civil', '49', 'waiting', 'absolute', 'irish', 'nddc', 'revenue', 'hitch', 'members', 'listinfo', 'me', 'we', 'yours', 'niger', 'regards', '[', 'http', 'several', 'five', 'ten', 'contact', 'whose', 'reply', 'either', 'p', 'would', 'peoples', 'revenues', '/', 'firstly', 'group', 'in', 'have', 'oil', 'forward', 'new', 'k', 'first', 'to', 'although', 'placed', 'm', 'fourteen', 'www', 'other', 'us', 'ministry', 'free']
# ['prizemama', '1', '5', 'users', 'use', 'link', 'slim', 'un', '12', 'if', 'fastest', '10', 'for', ')', 'risk', 'of', 'you', 'please', 'this', 'legal', '3', 'your', 'cancer', '2', 'wish', 'mailman', '(', 'day', 'child', 'online', 'days', 'down', 'linux', 'subject:', 'below', 'growing', 'album', 'list', 'advice', "'", 'fight', '-', '206', ',', 'offer', ':', 'subscription', 'community', 'start', 'information', ']', 'join', 'get', 'lbs', 'ie', 'support', 'maintainer', 'a', 'listmaster', 'ilug', '.', '@', 'the', 'wonderful', 'irish', 'listinfo', 'manager', 'singles', 'deserve', '[', 'http', '!', '4', 'web', 'private', 'leave', '/', 'lose', 'group', '30', 'guaranteed', 'in', 'have', 'to', 'www', 's', 'photo', 'free']
# ['1', 'parts', 'included', 'will', '00', 'com', 'body', 'uri', 'surbl', 'as', '8', 'only', 'spamcop', 'mime', 'just', 'appears', '25', 'extra', 'be', '_', 'no', 'projecthoneypot', 'your', 'bjefladghikm', 'not', 'color', '2', 'attachments', 'mdaemon', 'her', '60', 'red', '08', 'subject:', 'id', 'req', 'from', 'sc', '64', 'contains', 'indentified', "'", 'font', 'version', 'hits', '%', 'spam', '-', '38', 'capitalspreads', ',', 'is', 'yes', 'subject', 'ws', 'file', ':', 'score', ']', 'required', 'ab', 'denham', '=', 'org', 'html', 'info', '*', 'at', 'autolearn', '.', '@', 'fontcolor', 'database', '50', 'multi', 'blacklisted', '0', 'it', 'domain', 'rbl', '[', '4', 'text', 'has', 'delivered', 'message', '/', 'tests', 'in', 're', 'to', 'm', '9', 's']
# ['email', '1', 'items', 'price', '5', 'ff', '00', '499', '229', '01', '7', 'also', 'titles', '#', 'top', '10', 'for', '1148', '$', 'on', 'bought', '529', '99', '599', '2003', 'office', '69', '90', 'or', '20046', 'system', ')', 'you', 'this', '15177', 'write', 'special', '6', '3', 'cs', 'acrobat', 'corel', 'by', 'flash', '279', 'opt', '2', 'based', '(', 'microsoft', 'bohsg', '85', 'save', 'software', 'subject:', 'requirements', 'available', 'sale', 'urce', 'antivirus', 'adobe', 'average', 'code', '2005', 'pro', 'windows', 'illustrator', 'list', 'versions', '31', 'see', '%', '03', 'zxghlajf', 'download', '-', 'sales', 'edition', 'kuc', ',', '11', '127', 'expires', 'v', 'microsoftchoose', '86', 'wavefrtl', 'coupon', 'xp', 'offer', 'maya', ':', 'view', 'these', 'ho', '92', 'st', 'now', 'alias', 'photoshop', 'manufacturer', 'customers', '*', 'a', 'customer', '20058', 'instant', 'review', 'draw', 'mx', '.', 'server', 'availability', 'search', 'rank', 'professional', '49', '|', 'unsubscribe', '429', '0', 'me', 'norton', 'longhorn', '!', 'august', '4', 'adobechoose', 'pl', 'date', '195546', 'symantec', 'more', '20032', 'in', 'new', '9', 'other', 'reviews', '156489', 'ms']
# ['work', '35', '1', 'permanent', 'program', 'com', '214', 'sorry', 'order', 'castillo', 'mail', 'send', '10006', 'charset', '8', 'return', 'do', 'following', 'per', '87', '10', 'priority', 'mime', '$', 'dose', 'authenticated', 'just', '99', 'qmail', '+', 'longer', 'copy', 'positive', 'content', ')', 'of', '0000', 'this', 'address', '3', 'type', '205', 'able', 'be', 'sex', 'no', 'projecthoneypot', 'low', 'your', 'out', '8859', 'by', 'squirrelmail', 'her', 'network', 'hi', 'tue', '(', 'addresses', '42', 'invoked', 'time', '24815823', 'subject:', 'id', 'incredibly', 'prices', 'i', 'unbeiivable', '170', 'below', 'soft', 'life', 'gzo', 'with', 'from', '2005', 'j', 'afraid', '66', 'mailer', 'agent', 'helo', "'", '19', 'iso', 'version', 'didn', 'unknown', '-', '220', 'is', ',', 'subject', 'keys', 'x', 'notice', ';', 've', 'net', 'error', '32', ':', 'ready', 'jul', 'deboel', 'right', 'importance', '=', 'transfer', 'org', 'html', '"', 'now', 'given', 'info', 'a', 'at', 'encoding', 'viagra', '?', '.', 'deliver', '@', 'bit', 'path', 'the', '57', 'received', 'gigas', '0', 'starting', 'it', 'smtp', '62', 'barry', 'boost', '162', 'http', '46', '!', 'wasn', 'line', 'mailwisconsin', 'accepts', '4', 't', 'user', 'date', 'normal', 'text', 'message', '/', 'to', 'm', 'failure', 'up']
# ['this', '.', 'sure', '1000', 'use', 'your', '-', 'home', 'value', 'by', 'claim', 'exclusiverewards', 'area', 'find', '(', 'can', 'depot', 'for', 'card', 'subject:', '$', 'in', 'gift', 'udexhoyp', 'a', ')', 'free', 'you', 'were']
# ['into', '?', 'marketing', '.', 'business', 'click', 'hand', 'check', 'perfect', 'the', 'see', 'your', 'logodentity', 'out', '-', 'thinking', 'future', ',', 'sampies', 'artwork', 'make', 'charset', 'under', 'brinq', '8', 'our', 'stand', 'hot', 'koi', 'amonq', 'competitors', 'and', 'its', 'web', 'breath', '>', 'start', 'carefui', 'ioqos', 'subject:', 'sites', 'r', 'prices', 'fresh', 'revamping', 'logo', '=', 'front', 'offers', 'breathing', 'custom', 'these', 'toois', 'just', 'air', 'success', 'ciick', 'life', 'stationery', 'new', '"', 'visual', 'identity', 'powerful', 'from', 'here', 'to', 'wiil', 'a', 'design', 'end', 'away', 'of', 'you', 'are', 'creative']
# ['maximum', '19', '.', '95', 'be', 'the', 'media', 'com', 'art', '-', 'explanation', '7', 'cannot', ',', 'creator', '0', 'softs', 'roxio', 'broadcasters', 'easy', 'http', 'choose', ':', 'all', 'man', 'branded', 'subject:', 'sing', 'when', '$', 'i', 'more', '/', 'kinds', 'ceases', 'wxget', 'to', 'a', 'he', 'minimal']
# ['allows', 'process', '5', 'shortly', 'formula', 'neuro', 'control', 'partner', 'php', 'look', 'regulates', 'high', 'actually', 'product', 'only', 'and', '10', 'thanks', 'brain', 'cures', 'pleasure', 'quickly', 'on', 'did', 'longer', 'or', 'interferes', 'extra', 'performance', 'few', 'of', 'you', 'hello', 'rr', 'sex', 'endocrine', 'no', 'your', 'therapy', 'ejaculate', 'not', 'guilt', 'within', 'premature', 'time', 'before', 'subject:', 'sexual', 'here', 'with', 'penetration', 'feelings', 'last', 'that', 'occurs', 'et', '-', 'minutes', 'male', 'through', ',', 'is', 'emotion', 'meds', 'locally', 'centers', 'after', 'net', ':', 'but', 'when', 'frustration', 'causes', 'times', '"', 'a', 'ejaculation', 'acts', 'pathway', 'herbal', 'hormonal', '?', '.', 'the', 'tabboulehs', 'organs', 'embarrassment', 'depression', 'it', 'non', 'http', 'stops', 'both', '/', 'in', 'to', 'too', 'without']
# ['buy', 'this', 'price', 'please', 'instructions', "'", 'marketing', 'source', '.', 'car', 'follow', 'click', 'search', 'the', '24', 'because', 'internet', 'no', 'used', 'your', '-', 'receive', 'owned', 'received', 'at', '7', 'is', ',', 'unsubscribe', 'pre', 'x', 'list', 'selected', 'wish', 've', 'bottom', 'best', 'our', 'signed', 'if', '!', 'online', 'vehicle', 'offer', 'and', 'exclusive', 'for', 'subject:', 'next', 'on', 'message', 'get', 'offers', 'here', 'these', 'longer', 'have', 'new', 'emessaging', 'to', 'from', 'exciting', 'discounts', 'mailing', 'a', 'carefully', 'up', 's', 'one', 'of', 'you', 'partners']
# ['this', 'war', 'part', '?', "'", 'lost', '.', 'could', 'be', 'americans', 'check', 'com', 'excellence', 'gretan', 'perfection', 'very', 'your', 'out', 'better', 'patience', 'not', 'is', 'power', ',', 'awesome', 'teaching', 'ss', 'wish', 've', 'product', 'cheerful', 'http', 'human', 'if', 'mind', 'and', 'time', ':', 'for', 'all', 'important', 'compound', 'subject:', 'geography', '/', 'way', 'killed', 'god', 'new', 'life', 're', 'bro', 'www', 'a', 's', 'vigorous', 'strive', 'of', 'you']
# ['email', '35', 'rock', '1934', 'never', 'level', 'seven', 'hoiding', 'measure', 'kind', 'contained', 'than', 'preservation', 'market', 'can', 'party', 'remember', 'wirelessiy', 'read', 'for', 'services', 'newsietter', 'appiications', 'chemica', 'action', 'accounting', ')', 'fueis', 'limited', 'history', 'unsecured', 'september', 'differ', 'no', 'omit', 'out', 'by', 'sector', '2', 'speciaily', 'none', 'constant', '(', 'outstanding', 'invoive', 'service', 'time', 'potentiaily', '2001', 'create', 'b', 'necessary', 'provide', 'here', 'maybe', 'verge', 'from', 'safe', 'confiict', 'must', 'enabie', 'others', 'application', 'thorough', 'advantage', 'features', 'requires', 'could', 'forrester', 'pioneer', 'space', 'guarantee', 'investors', 'moment', 'projects', 'through', 'is', 'compensation', '11', 'operating', 'notice', 'compieteness', 'emergency', 'gives', 'noting', 'transmit', 'beiieves', 'material', 'construed', 'need', 'represent', 'deveioping', 'inc', 'vinobie', 'a', 'customers', 'at', 'automation', 'reiiabie', 'personnel', '.', 'aiso', 'factual', 'integration', 'terms', 'handier', 'micro', 'tags', 'officer', 'works', '|', '21', 'nuciear', 'websites', '0', 'vaiuabie', 'economy', 'companies', 'entry', 'tracking', 'excitement', 'majority', 'near', 'leg', 'occur', '/', 'lose', 'investment', 'in', 'even', 'timing', 'fiiling', 'understands', 'favorabie', 'price', 'june', 'aware', 'foresee', 'advises', 'discloses', 'trapped', 'provided', 'government', 'huge', 'historica', 'completed', 'related', 'ports', 'high', 'certain', 'only', 'wirelessly', 'do', 'parties', 'fiiings', 'inciuding', 'report', 'stockhoider', 'happening', 'does', 'sma', 'misleading', 'expects', 'reliance', 'focus', 'therein', 'big', 'dollars', 'innovative', 'advisor', 'personal', 'rfid', 'position', 'advancing', 'statements', 'conditions', 'returns', 'of', 'industry', 'present', 'materiais', 'mining', 'emai', 'segments', 'wil', 'risks', 'evaiuate', 'become', 'anticipates', 'spending', 'ocations', 'within', 'sha', 'based', 'selected', 'many', 'state', 'truiy', 'readers', 'ows', 'danger', 'such', 'suppiy', 'believes', 'before', 'confiicted', 'mines', 'liquids', 'pertaining', 'appiication', 'short', 'refining', 'imit', 'contains', "'", 'frequency', 'further', 'referenced', 'investments', 'products', 'great', 'percent', 'results', 'chain', 'see', 'oi', 'rf', '&', 'fal', 'where', 'u', 'yet', 'couid', 'was', 'ightning', 'securities', 'over', 'states', 'assist', 'deemed', 'research', 'achieve', 'machines', 'compliance', 'identify', 'physica', 'two', 'calif', 'view', 'sources', 'ob', 'these', 'registered', 'safety', 'paid', 'basis', 'given', 'money', 'ucrative', 'ensuring', 'into', 'review', 'business', 'wireiessiy', 'require', 'reiated', 'hands', 'facts', 'professional', 'detection', 'vinoble', 'resuits', 'events', 'solicitation', 'protective', 'we', 'it', 'increasing', 'beliefs', 'ed', 'wire', 'transportation', 'may', 'expanding', 'security', 'changed', 'locations', 'seek', 'have', 'forward', 'cause', 'water', 'sec', 'wel', 'although', 'too', 'other', 'resource', 'plans', 'tax', 'diligence', '5', 'due', 'use', 'homeland', 'afford', 'resuiting', 'lega', 'rocket', 'as', '12', 'needed', 'our', 'sensors', 'hot', 'transit', 'opportune', 'foreseeable', 'discussions', 'and', 'actua', '27', 'all', 'possibie', 'there', 'speed', 'radio', 'expected', 'advertisement', '$', 'any', 'predictions', 'acceptance', 'ourselves', 'personne', 'nationa', 'twelve', 'extraction', 'aiways', 'capitalize', 'estimates', 'risk', 'you', 'welis', 'director', 'news', 'what', 'commodities', 'materiaily', 'numerous', 'along', 'be', 'projections', 'might', 'featured', 'already', 'especiaily', 'airports', 'sectors', 'landscape', 'factors', 'effort', 'giga', 'providing', 'set', 'eclipse', 'wrong', 'filings', 'why', 'investing', 'faciiities', 'otcbb', 'pubiic', 'which', 'subject:', 'affiiiate', 'interest', 'threat', 'united', 'retai', 'with', '17', '2005', 'actions', 'ail', 'today', 'woridwide', 'rapidly', 'sa ...
# ['their', 'legal', 'prescription', 'medical', '.', 'everyone', 'sex', 'be', '24', 'the', 'lurks', 'experience', 'stone', '-', 'essential', 'minutes', ',', 'is', 'under', 'every', 'licensed', 'hours', '10', 'for', 'gives', 'medications', 'would', 'before', 'subject:', 'mistakes', 'mistake', 'life', 'name', '36', 'to', 'music', 'politician', 'guidance', 'a', 'without', 'lasts', 'of']
# ['?', 'good', 'news', '.', 'enemies', 'each', 'them', 'could', 'be', 'the', 'forgive', 'com', 'springs', 'those', 'bad', 'your', 'suum', 'stockinged', 'better', 'penis', 'who', 'is', 'cannot', 'cruelty', 'eternal', 'think', 'annoys', ',', 'ss', 'it', 'wish', 'much', '(', 'own', ';', 'amusement', 'http', 'cuique', 'siratu', 'so', 'about', 'extreme', ':', 'his', 'always', 'like', 'subject:', 'goes', 'clogs', 'growth', '/', 'in', 'happiness', 'to', 'www', 'nothing', 'feet', ')', 'hope', 'of', 'you']
# ['email', '1', 'wiley', 'full', '1000', 'will', 'com', 'uv', '214', 'pt', 'send', '#', '335', 'if', 'do', 'printing', '105', 'and', 'wileyprint', 'for', 'like', 'dallas', '$', 'any', 'on', 'just', 'offers', 'coated', 'or', 'few', 'of', 'you', 'methods', 'please', 'this', 'little', 'exhibitor', 'something', 'be', 'your', 'out', 'expo', 'by', '150', 'ave', 'quality', 'color', 'opt', 'however', '75205', 'time', 'an', 'subject:', 'prices', 'wants', 'brochures', 'here', '000', 'tx', 'below', 'with', 'postcards', 'prospective', '14', 'design', 'last', 'are', '0908', 'products', 'hand', 'great', 'that', 'sided', 'phone', '0308', '&', '-', 'through', 'fax', 'is', ',', 'subject', 'ever', 'show', 'different', ':', 'paper', 'looking', 'examples', 'two', 'cole', 'these', 'need', 'gloss', 'interested', 'info', 'a', 'customers', 'note', '100', 'going', '.', 'business', '@', 'stock', 'the', 'remove', 'offering', '443', 'around', 'me', '4650', '55', 'tsa', 'line', 'contact', 'reply', 'help', 'corner', 'would', 'cards', 'text', 'ideas', 'print', 'in', 'first', 'to', 'us', 'one', 'collateral']
# ['destiny', 'viagra', '.', 'what', 'answer', 'search', 'that', 'the', 'deserves', '%', 'anatomy', 'not', ',', 'is', 'ravishing', 'beginning', 'over', 'pharmacy', 'oh', 'it', 'cheapest', 'every', 'best', 'brandnames', '!', 'online', 'and', 'cialis', 'for', 'save', 'propecia', 'like', 'an', 'subject:', 'dear', 'question', 'thing', 'a', 'of', '80', 'amour']
# ['work', '1', '5', '09', 'permanent', 'program', 'com', '214', 'sorry', '09360462', 'order', 'castillo', 'mail', 'send', '50346', '#', 'charset', 'bbtec', '8', 'return', 'find', 'do', 'port', 'following', 'per', '87', '10', 'for', 'priority', 'mime', '$', 'notify', 'any', 'authenticated', 'just', 'dose', '99', 'qmail', '+', 'copy', 'positive', '51', 'pdt', 'content', ')', 'nic', '20', 'host', 'of', '50352', '0000', 'this', 'unbelivabie', '3', 'type', '205', 'able', 'sex', 'projecthoneypot', 'low', 'your', 'out', '8859', 'by', 'squirrelmail', 'amavisd', '2', 'her', 'network', 'hi', 'tue', '(', 'addresses', '42', 'invoked', '0700', 'time', 'yahoobb', 'subject:', 'id', 'incredibly', 'prices', 'i', 'below', 'soft', 'life', 'gzo', 'with', 'from', '2005', 'j', 'afraid', '66', 'mailer', '46679', 'agent', 'helo', "'", '19', 'iso', 'version', 'didn', 'unknown', '03', '-', '220', 'is', ',', 'subject', 'x', 'named', '127', '220056020109', 'notice', ';', 've', 'net', 'error', '50355', ':', 'ready', 'jul', ']', 'right', 'importance', '=', 'transfer', 'org', 'html', '"', 'now', 'scanned', 'given', 'alias', 'a', 'at', 'virus', 'encoding', 'viagra', '?', '.', 'deliver', '@', 'bit', 'path', 'the', '58', '50', 'localhost', '109', '57', 'received', 'couldn', 'cdsnet', '0', 'starting', 'it', 'smtp', '62', 'barry', 'boost', '[', 'bb', 'http', 'wasn', '46', 'line', 'mailwisconsin', '!', '4', 't', 'user', 'date', 'normal', 'text', 'delivered', 'message', 'internetcds', '/', '56', '10024', 'new', 'to', 'm', 'failure', 'up']
# ['this', '.', 'sure', '1000', 'qprkelmv', 'use', 'your', '-', 'home', 'value', 'by', 'claim', 'exclusiverewards', 'area', 'find', '(', 'can', 'depot', 'for', 'card', 'subject:', '$', 'in', 'gift', 'a', ')', 'free', 'you', 'were']
# ...
# ['process', 'will', '3240', 'call', 'continue', 'look', '01', 'systems', 'as', 'shirley', 'if', 'do', 'and', '10', 'thanks', 'for', 'all', 'vince', 'ely', 'on', 'roberts', 'system', 'of', 'you', 'gary', 'please', 'this', 'mike', 'week', 'what', 'really', 'paige', 'be', 'inform', 'moore', 'stella', 'by', 'possible', 'weekend', 'time', 'go', 'pull', '08', 'crenshaw', 'subject:', 'before', 'next', 'i', 'am', 'with', 'billing', 'j', 'are', 'list', "'", 'wouldn', 'belongs', 'pm', 'welcome', 'that', '24', 'regarding', 'see', '-', 'kaminski', ',', 'is', 'corp', 'subject', 'expect', 'cc', 'make', 'x', 'over', '2000', 'appreciate', ':', 'cox', 'location', 'll', 'information', 'connection', 'additional', 'when', 'get', 'need', 'now', '47', 'info', 'a', '.', 'kevin', '@', 'speaking', 'ect', 'the', 'installing', '34710', 'avistar', 'enron', 'me', 'we', 'it', 'regards', 'hou', 'd', 'desk', 't', 'thank', 'would', 'date', 'more', '/', 'monday', '54', 'have', 'in', 're', 'to', 'g', 'cable', 's', 'forwarded', 'eb']
# ['email', '1', '1999', 'plan', 'bflassociates', 'project', '5', 'response', 'plain', 'existing', 'language', 'will', 'organization', 'attached', 'mailo', '00', 'accept', 'lower', 'believe', 'com', '18', 'proposal', 'talk', 'means', 'look', '01', '7', '23', 'brief', 'also', 'involved', 'desire', 'jan', 'charset', 'concept', 'health', '8', 'can', 'only', 'our', 'if', 'postmaster', 'potential', 'per', 'and', 'opportunity', 'global', 'my', 'thanks', 'for', 'does', '10', 'yesterday', 'there', 'vince', 'rs', 'priority', 'mime', 'still', 'like', 'thursday', 'thereby', 'meeting', 'biggest', 'on', 'did', 'ltd', '25', 'understand', 'should', 'content', ')', 'willing', 'participate', 'founders', 'arfsten', 'of', 'you', 'workload', 'this', 'good', '6', '3', 'type', 'conceptually', 'lnintol', 'cck', 'might', 'very', 'solution', 'en', 'care', 'interesting', 'already', 'become', 'by', 'reward', 'not', 'conversation', 'marketplace', '05', '2', 'possible', 'national', 'pre', '(', 'enterprise', 'seems', 'intl', 'bfl', 'nscpcd', 'about', 'january', 'us', '00000000', 'an', '2001', 'subject:', 'regret', 'id', 'needing', 'asked', 'i', 'b', 'people', 'am', 'banks', '172', 'with', 'from', 'intermediahosting', '17', 'confidentially', '16', 'hope', '713', 'associates', 'mailer', 'update', "'", 'attack', 'pm', 'outbound', 'unverified', '15', 'further', 'version', 'that', '24', 'having', 'ascii', 'mozilla', 'win', 'mcd', '-', '0500', 'reverse', 'vkamins', 'u', 'xaal', 'was', 'kaminski', ',', 'is', 'thu', 'allow', 'subject', 'corp', 'cc', 'technologies', 'wed', 'x', 'release', '0600', 'skyrocketing', 'vision', 'make', 'concepts', '34', ';', 'economic', '192', 'problem', '965', 'december', 'router', 'c', 'developing', ':', ']', 'impact', '37', 'looking', 'importance', '=', 'al', 'mimetrack', 'transfer', 'these', '09075930', 'need', 'attractive', 'profit', 'come', 'mark', '36', '"', '47', 'a', '140', 'at', '45', 'esmtp', 'were', 'original', 'nahou', 'sent', 'encoding', 'ceo', '.', 'inefficient', 'business', '@', 'bit', 'costs', 'detect', 'loop', 'the', '58', 'dramatically', '28', 'highly', 'est', 'model', 'received', '49', 'gmt', '|', 'think', '2158', '0', 'shared', 'enron', 'ultimately', 'me', 'smtp', 'it', 'msmswolpx', 'participants', 'increasing', '[', 'smtprs', '4', 'reply', '98', 'stage', 'date', 'status', 'normal', 'serialize', 'text', 'would', 'help', 'blood', 'has', '2799', 'message', '/', 'fwd', 'morning', 'commodity', 'more', 'lay', '54', 'in', 'forward', '152', 'new', 're', 'to', 'm', '9', 'ver', 's', 'enormous', 'up', 'forwarded', 'one', 'involve', 'reality']
# ['work', '1', 'items', 'talked', 'plan', '5', 'will', '00', 'degiacinto', 'com', 'call', 'future', 'talk', 'forth', 'value', '01', 'tomorrow', 'piazze', 'mail', 'houston', '#', 'team', '8', 'return', 'as', 'narrow', 'can', 'matter', 'best', 'if', 'coordinate', 'our', 'contacting', 'and', 'facilitate', 'jhenders', 'my', 'thanks', 'for', 'clayton', 'services', 'mccarty', 'vince', 'like', 'thursday', 'vittal', 'meeting', 'assistant', 'focus', 'on', 'any', 'degiacic', 'understand', 'or', '06', ')', 'lessar', 'of', 'you', 'speak', 'please', 'address', 'week', '853', '3', 'maheshram', '9554', 'be', 'inform', 'planning', 'video', 'very', 'by', 'john', 'omar', 'feerick', '2', 'donna', 'ees', 'person', 'set', 'hi', 'including', '02', 'setting', '(', 'room', 'days', 'time', 'melinda', 'up', 'building', 'scope', '2001', 'us', 'subject:', 'people', 'before', 'next', 'i', 'provide', 'won', 'available', 'corley', 'below', 'perhaps', 'with', 'from', 'j', 'cummins', '04', '713', 'dial', 'recommends', 'last', 'are', 'scheduling', '31', "'", 'marketing', 'pm', '43', '15', 'could', 'products', 'that', 'regarding', 'having', 'wonder', 'phone', 'see', '03', '-', 'number', 'teleconference', 'him', 'newpower', 'kaminski', ',', 'is', 'corp', 'subject', 'distribution', 'cc', 'travelling', 'x', 'ensure', 'reserved', '34', 'until', 'bassal', 'appreciate', 'c', 'stephen', 'different', 'easiest', 'so', '32', 'ny', 'between', 'getting', ':', 'whatever', 'location', 'using', 'videoconference', 'christie', 'conference', 'join', 'hopefully', 'two', '31641', 'retail', 'now', 'come', '"', 'tiger', 'added', 'a', 'at', 'prefer', 'henderson', 'lpm', 'busy', 'melissa', 'specific', 'into', '?', 'sent', 'give', '.', '@', 'via', 'the', 'ect', 'mohn', '50', 'together', 'received', 'well', 'upenn', 'telephone', 'think', 'enron', 'me', 'we', 'it', 'again', 'expectations', 'feb', '13', '!', 'hou', 'voice', '4', 't', 'his', 'let', 'help', 'edu', 'would', 'both', 'marc', '/', 'wharton', 'morning', '30', 'patrick', 'trouble', 'have', 'in', 'know', 're', 'to', 'promotion', 'commensurate', 'm', 'include', 's', '07', 'he', 'forwarded', 'dennis']
# ['1', '09', '5', 'sorry', 'tomorrow', 'briefly', 'return', 'can', 'shirley', 'and', 'thanks', 'for', 'unable', 'vince', 'meeting', 'on', 'just', 'or', 'bet', 'few', 'you', 'this', 'what', 'wanted', 'urgent', 'out', 'not', '2', 'rescheduling', 'shalesh', 'afternoon', '08', 'crenshaw', 'subject:', 'before', 'i', 'am', 'available', 'sometime', 'with', 'from', 'j', 'are', 'today', "'", '19', 'pm', 'working', 'martin', 'minutes', 'kaminski', 'is', ',', 'subject', 'wait', 'make', 'cc', 'until', 'after', '2000', 'isn', ':', 'but', 'late', '36', 'a', 'since', '?', '.', '@', 'the', 'ect', 'we', 'it', 'meet', 'informal', 'hou', 'try', 'lin', 't', 'let', 'leave', '/', 'morning', '30', 'have', 'timing', 're', 'to', 'catch', 's', 'perhaps', 'otherwise']
# ['ben', '.', 'will', 'be', 'interview', 'three', 'regards', 'afternoon', 'role', 'for', 'all', 'subject:', 'guys', 'available', 'monday', 'rac', 'these', 'support', 'cvs', 'candidates', 'of']
# ['this', 'past', '?', '.', 'shortly', 'will', '15', '@', 'issler', 'double', 'structure', 'ect', 'the', 'call', 'use', '18', '03', '-', 'talk', 'kaminski', 'osl', ',', 'power', 'subject', 'thor', 'cc', 'we', '02', 'it', '12', 'product', '2000', 'do', 'hou', 'about', ':', 'thanks', 'for', 'swap', 'vince', 'you', 'subject:', 'any', 'models', '/', 'lien', 'am', 'on', 'have', 'times', 'in', 're', 'to', 'modeled', 'j', 'a', 'up', 'few', 'paulo']
# ['past', 'instructions', 'later', '5', 'will', 'shall', '00', 'italian', 'com', 'arrive', 'continue', 'home', 'look', 'lights', '23', 'forest', 'send', 'stop', 'as', 'aol', 'can', 'intersection', 'and', 'my', '10', 'for', 'yards', 'all', 'there', 'like', 'vince', 'still', 'meeting', 'on', 'just', 'patrycja', 'big', '300', 'mall', 'stay', ')', 'you', 'hello', 'address', '3', 'along', 'nyc', 'be', 'how', 'your', '367', 'wish', '(', 'woodlands', 'job', 'about', 'exxonmobil', 'save', 'mar', 'go', 'an', 'building', 'subject:', 'before', 'next', 'i', 'trip', 'saturday', 'hotmail', 'with', 'block', 'back', 'from', '713', 'are', 'sender', 'pass', "'", 'greetings', 'phone', 'case', 'associated', '-', 'was', 'through', ',', 'vkaminski', '9960', 'subject', '281', 'cc', 'miles', 'restaurant', 'exit', 'after', '2000', 'place', 'research', ':', 'previous', 'mon', 'right', 'pdalecka', 'early', 'apple', '898', 'get', 'conroe', 'a', 'at', '45', 'delete', '?', 'snowbird', '.', 'cell', '@', 'road', 'close', 'the', 'traveling', 'lot', 'carrabba', 'according', 'est', 'received', 'works', 'take', 'around', 'me', 'it', 'meet', 'sawdust', '13', '4', '200', 'reply', 'let', 'date', '26', 'p', 'feeder', 'leave', 'message', '5377', 'in', 'have', 'forward', '22', 're', 'to', 'm', 's']
# ['plan', 'nice', '09', 'answer', 'will', '00', 'call', 'also', 'attending', 'pierre', 'can', 'do', 'if', 'shirley', 'yeager', 'and', 'friday', 'told', 'for', 'thanks', 'all', 'suggestions', 'thursday', 'meeting', 'any', 'on', 'just', 'final', 'or', '06', ')', 'of', 'you', 'hello', 'please', 'part', 'good', 'news', 'forwarded', 'really', 'be', 'planning', 'scott', 'your', 'by', 'reservations', 'night', '(', 'open', 'go', 'crenshaw', 'subject:', 'owner', 'sheryl', 'i', 'am', 'here', 'management', 'with', 'restaurants', 'she', 'offsite', 'are', 'list', 'today', 'dinner', "'", 'senior', 'pm', '15', 'them', 'that', '24', 'bad', 'see', '03', '-', 'season', ',', 'is', 'subject', 'cc', 'make', 'restaurant', 'knows', '2000', 'summer', ':', 'april', 'but', 'wife', 'hotel', 'question', 'breckenridge', 'at', 'going', '?', 'thuraisingham', '29', '.', 'everyone', '@', 'close', 'check', 'the', 'ect', 'nd', '28', 'communications', 'enron', 'me', 'we', 'it', 'participants', 'dinners', 'again', 'another', '!', 'hou', 'may', 'most', 'let', 'entire', '/', 'group', 'in', 'have', 'ravi', 'know', '22', 're', 'to', 's', 'other', 'us', 'perhaps', '07', 'invited', 'lara']
# ['items', 'corrections', '98004', 'gas', '5', '3719001', 'will', 'attached', 'rd', 'com', 'call', 'use', 'returned', 'sorry', '1092', 'home', 'galley', '01', 'also', 'tomorrow', '23', 'mail', 'dates', '3719010', 'ask', 'market', 'contracts', 'only', 'made', 'shirley', 'if', 'can', 'certainly', 'editor', 'and', 'read', 'my', 'thanks', 'for', 'pages', 'all', 'joyce', '10', 'function', 'vince', 'still', '76798', 'any', 'on', 'latest', 'tracing', 'segment', '710', 'office', 'understand', 'or', '06', ')', 'pay', 'htm', 'edit', 'of', 'you', 'this', 'palmer', 'week', 'cindy', 'left', 'something', 'be', '_', 'arrives', 'manuscript', 'anything', 'very', 'your', 'minor', 'by', 'john', 'not', 'zipped', 'ago', '2', 'ended', 'department', 'recent', 'however', 'corrected', '02', 'bold', 'outstanding', '(', '3719004', 'change', 'day', 'desktop', 'word', 'making', 'article', 'publisher', 'down', 'about', 'missed', 'trying', '2001', 'subject:', 'e', 'i', 'b', 'am', 'tx', 'book', '3719006', 'with', 'she', 'arose', 'waco', 'document', 'briefcase', 'from', 'j', '04', 'hope', 'finance', 'hires', 'windows', 'doesn', 'revision', 'versions', 'scheduling', "'", 'pm', '15', 'them', 'version', 'baylor', 'that', 'martin', 'regarding', '\\', 'fine', 'see', 'haven', '-', 'incorporated', 'vkamins', 'mary', 'was', 'fax', ',', 'is', '3719003', 'subject', 'cc', 'make', 'box', 'converted', 'over', '0600', 'chair', 'concerned', 'oversight', 'confusion', 'collins', 'problem', 'c', 'file', 'so', ':', 'but', 'paper', '37', 'gave', 'when', 'hsb', 'two', 'relate', 'these', 'papers', 'greatly', 'html', 'carr', '"', '47', 'mark', 'conflict', 'added', 'a', 'at', 'were', '.', 'business', '@', 'disappointed', 'the', '3719005', '3719008', 'face', 'received', 'well', 'ok', 'university', 'take', 'po', 'enron', 'me', 'we', 'looks', 'it', 'nor', 'again', '3719009', 'martinj', 'feb', 'http', 'complete', 'd', '4473', 'web', 'edits', 't', 'most', 'attachment', '>', 'help', 'p', 'edu', '3719007', 'morning', '/', 'got', '254', 'reading', 'have', 'spoke', 'in', 'new', 're', 'to', 'earlier', 'wrote', 's', 'up', 'end', 'references']
# ['march', 'email', 'response', 'event', 'unlawful', 'clients', 'organization', 'garp', 'contained', 'houston', 'related', 'market', 'publications', 'individuals', 'access', 'as', 'contracts', 'can', 'our', 'made', 'if', 'following', 'york', 'capm', 'and', 'global', 'panel', 'volunteers', 'for', 'kpmg', 'suggestions', 'like', 'reliance', 'meeting', 'assistant', 'focus', 'on', 'sponsor', 'any', 'neeley', 'bringing', 'letter', 'action', 'or', ')', 'conditions', 'risk', 'host', 'arrangements', 'speak', 'of', 'you', 'please', 'derivative', 'aspects', 'this', 'corporate', 'be', 'respectfully', 'frank', 'opinions', 'capital', 'your', 'derivatives', 'expense', 'reward', 'by', 'not', 'area', '(', 'primary', 'making', 'governing', 'estimating', 'prohibited', 'measurement', 'taken', 'an', 'behavioral', 'subject:', 'fyi', 'trading', 'putting', 'measuring', 'futures', 'with', 'from', 'finance', 'are', 'premium', 'advice', 'greetings', 'school', 'that', 'privileged', '&', 'else', 'where', 'liquidity', 'addressee', ',', 'is', 'identified', 'general', 'disclosure', 'distribution', 'subject', ';', 'addressed', 'so', 'research', 'tcu', 'information', 'markets', 'additional', 'looking', 'when', 'unauthorized', 'these', 'confidential', 'need', 'papers', 'expressed', 'interested', 'seeking', 'come', 'courses', 'journal', 'a', 'financial', 'at', 'professionals', 'resources', 'review', '.', 'business', 'topics', 'via', 'city', 'solely', 'recipient', 'the', 'terms', 'currently', 'steve', 'respond', 'together', 'anyone', 'scheduled', 'well', 'cost', 'teaches', 'me', 'we', 'it', '!', 'may', 'hayden', 'mann', 'his', 'association', 'let', 'copying', 'professor', 'would', 'date', 'cover', 'omitted', 'legally', 'approaches', 'client', 'have', 'in', 'know', 'forward', 'new', 'studies', 'engagement', 'to', 'intended', 'include', 'he', 'one']
# ['strange', 'said', 'little', 'colorado', '.', '@', 'feel', 'ect', 'the', '-', '57', 'uncomofortable', 'by', ',', 'samer', 'communications', 'subject', 'enron', 'cc', '11', 'as', 'it', 'skip', '2000', 'hou', 'and', '10', ':', 'thanks', '08', 'would', 'subject:', 'fyi', 'i', 'on', '/', 'am', 'trip', 'though', '25', 'stinson', 'gibner', 'to', 'from', '17', 'a', 'forwarded', 'prefer', 'takriti']
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
emails.tail()
# Out:
#                                                    text  spam
# 5723  Subject: re : research and development charges...     0
# 5724  Subject: re : receipts from visit  jim ,  than...     0
# 5725  Subject: re : enron case study update  wow ! a...     0
# 5726  Subject: re : interest  david ,  please , call...     0
# 5727  Subject: news : aurora 5 . 2 update  aurora ve...     0

# %%
# Test your preprocessing by testing on the first email

# %% [markdown]
# ## Step 3: Calculate Prior Probabilities
# Let's calculate the basic probability of an email being spam.

# %%
# TODO: Calculate the following:
# 1. Total number of emails
# 2. Number of spam emails
# 3. Probability of spam

num_emails =len(emails) # Your code here
num_spam = sum(email for email in emails['spam'])  # Your code here
spam_probability = num_spam / num_emails if num_emails > 0 else 0 # Your code here


print(f"Number of emails: {num_emails}")
print(f"Number of spam emails: {num_spam}")
print(f"Probability of spam: {spam_probability:.4f}")

# HINT: Use len(emails) for total count
# HINT: Use sum(emails['spam']) for spam count
# Out:
# Number of emails: 5728
# Number of spam emails: 1368
# Probability of spam: 0.2388

# %% [markdown]
# ## Step 4: Training the Model
# Now we'll build our Naive Bayes model by counting word occurrences in spam and ham emails.

# %%
def train_naive_bayes(emails_data):
    """
    Train a Naive Bayes model on email data
    
    Parameters:
        emails_data (DataFrame): DataFrame with 'text' and 'spam' columns
    
    Returns:
        dict: Dictionary with word frequencies in spam and ham emails
    """
     # TODO: Create a dictionary to store word frequencies
    # For each word, store counts of its occurrence in spam and ham email
    
    model = {}

    for _, email in emails_data.iterrows():
        words = email['text'].split()  
        is_spam = email['spam']
        
       
        for word in words:
            if word not in model:
                model[word] = {'spam': 1, 'ham': 1}
                
            if is_spam:
                model[word]['spam'] += 1
            else:
                model[word]['ham'] += 1

    return model
    # Your code here
    # HINT: Initialize counts with 1 (Laplace smoothing)
    # HINT: Structure: model[word] = {'spam': count, 'ham': count}

# %%
model = train_naive_bayes(emails)

# %%
# Test your model with some words
# Examples: 'lottery', 'sale', 'meeting'

print(model["lottery"])
print(model['sale'])
print(model['meeting'])
# Out:
# {'spam': 21, 'ham': 1}
# {'spam': 51, 'ham': 57}
# {'spam': 14, 'ham': 1773}

# %% [markdown]
# ## Step 5: Implementing the Prediction Function
# Finally, let's implement the function to predict whether an email is spam.

# %%
import math
def predict_naive_bayes(email_text, model, num_spam, num_ham):
    """
    Predict whether an email is spam using Naive Bayes
    
    Parameters:
        email_text (str): The text of the email to classify
        model (dict): Trained Naive Bayes model
        num_spam (int): Number of spam emails in training data
        num_ham (int): Number of ham emails in training data
    
    Returns:
        float: Probability that the email is spam
    """
    # TODO: Implement the Naive Bayes prediction
    # 1. Preprocess the email text
    # 2. Calculate probability using the Naive Bayes formula

    # Your code here
    words = email_text.split()
    
    # Calculate initial probabilities of spam and ham
    total_emails = num_spam + num_ham
    prob_spam = math.log(num_spam / total_emails)
    prob_ham = math.log(num_ham / total_emails)
    
    # Update probabilities based on word presence
    for word in words:
        if word in model:
            # Get word counts in spam and ham with Laplace smoothing
            spam_count = model[word]['spam']
            ham_count = model[word]['ham']
        else:
            # Default counts for unseen words (Laplace smoothing)
            spam_count = 1
            ham_count = 1

        # Calculate log probabilities for the word
        prob_spam += math.log(spam_count / (num_spam + 2))  # +2 for Laplace smoothing
        prob_ham += math.log(ham_count / (num_ham + 2))

    # Return probability as spam score (higher means more likely spam)
    spam_score = math.exp(prob_spam)
    ham_score = math.exp(prob_ham)
    return spam_score / (spam_score + ham_score) 
    # HINT: Use the log of probabilities to avoid numerical underflow
    # HINT: Remember to handle words not in the training data
    pass

# %%
# Test your prediction function
test_emails = [
    "lottery winner claim prize money",
    "meeting tomorrow at 3pm",
    "buy cheap watches online"
]

# %%
# and model is the dictionary from the `train_naive_bayes` function.

for email_text in test_emails:
    # Predict the probability that the email is spam
    spam_probability = predict_naive_bayes(email_text, model, num_spam, num_emails-num_spam)
    print(f"Email: {email_text}\nSpam Probability: {spam_probability:.4f}\n")
# Out:
# Email: lottery winner claim prize money
# Spam Probability: 1.0000
#
# Email: meeting tomorrow at 3pm
# Spam Probability: 0.0018
#
# Email: buy cheap watches online
# Spam Probability: 0.9983

# %% [markdown]
# ## Step 6: Wrap-up
# 1. How well did your model perform?
# 2. What challenges did you face while implementing it from scratch?
# 3. What improvements would you suggest for the future?

# %% [markdown]
# 1. The model accuracy was good
# 2. Since all steps are given not much challenges were there
# 3. It was beginner friendly

# %% [markdown]
# ### Notes (if any):
